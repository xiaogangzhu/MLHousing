# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
import seaborn as sns

# %% [markdown]
# - initial notes
# - see r for missing data patterns, looks like some one off houses, and lots missing data for lot frontage, garage yr built(prob no garage do loc and shape) masonry veneer area
# - most of SF categories skewed
# - pattern in month sold
# - should group categorical together
# - maybe make quality categoricals into numerical

# %%
raw = pd.read_csv('data/Ames_Housing_Price_Data.csv')
raw = raw.drop(raw.columns[0], axis=1)

# %%
base = raw.loc[raw['TotalBsmtSF']==0]
base.shape
# Out:
# (68, 81)

# %%
raw['BsmtQual'].isna().sum()
# Out:
# 69

# %%
raw.head()
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 0  909176150        856     126000          30       RL          NaN     7890
# 1  905476230       1049     139500         120       RL         42.0     4235
# 2  911128020       1001     124900          30  C (all)         60.0     6060
# 3  535377150       1039     114000          70       RL         80.0     8146
# 4  534177230       1665     227000          60       RL         70.0     8400
#
#   Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 1   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 3   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 4   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# ...

# %%
raw.FullBath.unique()
# Out:
# array([1, 2, 3, 0, 4])

# %%
raw.loc[raw.LotFrontage<]
# Out:
# --------------------------------------------------------------------
# NameError                          Traceback (most recent call last)
# <ipython-input-57-281572330d1d> in <module>
# ----> 1 raw.loc[raw.LotFrontage==NaN]
#
# NameError: name 'NaN' is not defined

# %%
raw.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec116c2b10>,
# ...
#       dtype=object)

# %%
raw.SalePrice.hist(bins=40)

# %%
rawls = raw.copy()
rawls.SalePrice =np.log(raw.SalePrice)

# %%
rawls.SalePrice.hist(bins=40)

# %%
rawls.loc[rawls.SalePrice<10]
# Out:
#            PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 427  902207130        832   9.456341          30       RM         68.0
#
#      LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 427     9656   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#     Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 427      OldTown       Norm       Norm     1Fam     1Story            2
#
#      OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 427            2       1923          1970     Gable  CompShg     AsbShng
#
#     Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 427     AsbShng       None         0.0        TA        Fa     BrkTil
#
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 427       Fa       Fa           No          Unf         0.0          Unf
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# ...

# %%
raw.describe()
# Out:
#                 PID    GrLivArea      SalePrice   MSSubClass  LotFrontage  \
# count  2.580000e+03  2580.000000    2580.000000  2580.000000  2118.000000
# mean   7.148300e+08  1486.039922  178059.623256    57.691860    68.516053
# std    1.886626e+08   488.650181   75031.089374    42.802105    22.835831
# min    5.263011e+08   334.000000   12789.000000    20.000000    21.000000
# 25%    5.313630e+08  1112.000000  129975.000000    20.000000    57.000000
# 50%    5.354546e+08  1436.000000  159900.000000    50.000000    68.000000
# 75%    9.071811e+08  1733.000000  209625.000000    70.000000    80.000000
# max    1.007100e+09  4676.000000  755000.000000   190.000000   313.000000
#
#              LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd  \
# count    2580.000000  2580.000000  2580.000000  2580.000000   2580.000000
# mean    10120.153488     6.046124     5.618605  1970.313953   1983.751938
# std      8126.937892     1.367590     1.122008    29.719705     20.490242
# ...

# %% [markdown]
# I think that partial sales only happen to more expensive homes but does not look that way

# %%
df = raw.loc[raw.SalePrice>400000]
df.loc[df.SaleCondition=='Partial'].shape
df.shape
# Out:
# (44, 81)

# %% [markdown]
# How Aiko plotted the scatterplot

# %%
raw[['GrLivArea', 'SalePrice']].plot(kind='scatter', x='GrLivArea', y='SalePrice')

# %%
raw.HouseStyle.value_counts()
# Out:
# 1Story    1288
# 2Story     773
# 1.5Fin     284
# SLvl       118
# SFoyer      70
# 2.5Unf      22
# 1.5Unf      19
# 2.5Fin       6
# Name: HouseStyle, dtype: int64

# %%
categorical = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'Electrical', 'CentralAir', 'HeatingQC', 'Heating', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'SaleType', 'SaleCondition', 'MiscFeature']

for feature in categorical:
    print(raw[feature].value_counts())
    print('')
# Out:
# RL         2008
# RM          418
# FV          113
# RH           21
# C (all)      17
# I (all)       2
# A (agr)       1
# Name: MSZoning, dtype: int64
#
# Pave    2570
# Grvl      10
# Name: Street, dtype: int64
#
# Grvl    105
# Pave     63
# Name: Alley, dtype: int64
#
# Reg    1641
# IR1     855
# IR2      71
# IR3      13
# Name: LotShape, dtype: int64
#
# Lvl    2337
# HLS      96
# Bnk      95
# Low      52
# Name: LandContour, dtype: int64
#
# AllPub    2578
# NoSewr       2
# Name: Utilities, dtype: int64
#
# Inside     1886
# Corner      439
# CulDSac     164
# FR2          78
# FR3          13
# Name: LotConfig, dtype: int64
#
# Gtl    2458
# Mod     109
# Sev      13
# Name: LandSlope, dtype: int64
#
# NAmes      410
# CollgCr    236
# OldTown    213
# Edwards    165
# Somerst    143
# Gilbert    143
# Sawyer     139
# NWAmes     123
# NridgHt    121
# SawyerW    113
# Mitchel    104
# BrkSide    103
# Crawfor     93
# IDOTRR      76
# NoRidge     67
# Timber      54
# ...

# %%
list(raw.dtypes)
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
# ...

# %% [markdown]
# ### Missingness

# %%
raw.isnull().sum(axis=0)
# Out:
# PID                 0
# GrLivArea           0
# SalePrice           0
# MSSubClass          0
# MSZoning            0
# LotFrontage       462
# LotArea             0
# Street              0
# Alley            2412
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType         14
# MasVnrArea         14
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           69
# BsmtCond           69
# BsmtExposure       71
# BsmtFinType1       69
# BsmtFinSF1          1
# BsmtFinType2       70
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# ...

# %%
raw.FireplaceQu.unique()
# Out:
# array(['Gd', nan, 'Ex', 'TA', 'Fa', 'Po'], dtype=object)

# %%
raw.loc[raw.TotalBsmtSF.isna()] #one house basement info nan instead 0 
# also one of two nan bathrooms
# Out:
#            PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 912  903230120        896      79000          20       RM         99.0
#
#      LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 912     5940   Pave   NaN      IR1         Lvl    AllPub       FR3       Gtl
#
#     Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 912      BrkSide      Feedr       Norm     1Fam     1Story            4
#
#      OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 912            7       1946          1950     Gable  CompShg     MetalSd
#
#     Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 912      CBlock       None         0.0        TA        TA      PConc
#
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 912      NaN      NaN          NaN          NaN         NaN          NaN
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# ...

# %%
raw.loc[raw.TotalBsmtSF==0]
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 5     908128060       1922     198500          85       RL         64.0
# 96    535457050        925      99000          20       RL         70.0
# 164   531475220       1882     160000          90       RL         75.0
# 209   905228050        660      63900          20       RL          NaN
# 215   535450160       1040      92900          90       RL         60.0
# 328   535327230       1764     100000          20       RL         71.0
# 336   908204180       1152      61500          90       RL         74.0
# 452   902427045        882      97000          20       RM         70.0
# 478   532351150       1654     119500          90       RM         68.0
# 495   902205010        612      45000          30       RM         50.0
# 552   531477040       2020     144000          90       RH         60.0
# 556   908204160       1152      82500          90       RL         74.0
# ...

# %%
raw.SaleCondition.unique()
# Out:
# array(['Normal', 'Partial', 'AdjLand', 'Abnorml', 'Alloca', 'Family'],
#       dtype=object)

# %%
import plotly.express as px

fig = px.scatter(raw, x="Neighborhood", y="SalePrice", color="MSZoning")


fig.show()
# Out:
# <div>
#
#
#             <div id="04523dec-dd0c-4157-a6c2-56feff192487" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("04523dec-dd0c-4157-a6c2-56feff192487")) {
#                     Plotly.newPlot(
#                         '04523dec-dd0c-4157-a6c2-56feff192487',
# ...

# %% [markdown]
# #### Grouping the Neigborhoods by price/area median

# %%
import clean1

# %%
raw_c = clean1.clean(raw)

# %%
raw_c = clean1.clean_category_var(raw_c)

# %%
# looking at original MSZoning 
raw_c['MSZoning'] = raw['MSZoning'].copy()

# %%
fig = px.scatter(raw_c, x="Neighborhood", y="SalePrice", color="MSZoning")
fig.show()
# shows MSZoning is being somewhat captured with our neighborhood tiers
# Out:
# <div>
#
#
#             <div id="09c6a3aa-0a5a-45f3-a42a-a550d9d3718a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("09c6a3aa-0a5a-45f3-a42a-a550d9d3718a")) {
#                     Plotly.newPlot(
#                         '09c6a3aa-0a5a-45f3-a42a-a550d9d3718a',
# ...

# %%
px.scatter(raw_c, x="BsmtQual", y="SalePrice", color='TotalBsmtSF')
# Out:
# <div>
#
#
#             <div id="214e7767-dfad-4295-bbac-a8e06273541a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("214e7767-dfad-4295-bbac-a8e06273541a")) {
#                     Plotly.newPlot(
#                         '214e7767-dfad-4295-bbac-a8e06273541a',
# ...

# %%
px.box(raw, x="HouseStyle", y="SalePrice")
# Out:
# <div>
#
#
#             <div id="e55e45a7-c841-43cf-bb5d-5ba25b82fbee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e55e45a7-c841-43cf-bb5d-5ba25b82fbee")) {
#                     Plotly.newPlot(
#                         'e55e45a7-c841-43cf-bb5d-5ba25b82fbee',
# ...

# %%
raw['TotalBath'] = raw['HalfBath']/2 + raw['BsmtFullBath'] + raw['BsmtHalfBath']/2 + raw['FullBath']
raw['BathRatio'] = raw.TotalBath/raw.BedroomAbvGr

# %%
px.box(raw, x="TotalBath", y="SalePrice")
# Out:
# <div>
#
#
#             <div id="43435778-9929-417d-9458-9a2e1b0f2e66" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43435778-9929-417d-9458-9a2e1b0f2e66")) {
#                     Plotly.newPlot(
#                         '43435778-9929-417d-9458-9a2e1b0f2e66',
# ...

# %%
px.box(raw, x="BedroomAbvGr", y="SalePrice")
# Out:
# <div>
#
#
#             <div id="768446b5-ef90-4b52-9981-c372b76dfa01" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("768446b5-ef90-4b52-9981-c372b76dfa01")) {
#                     Plotly.newPlot(
#                         '768446b5-ef90-4b52-9981-c372b76dfa01',
# ...

# %%
px.scatter(raw, x="BathRatio", y="SalePrice")
# Out:
# <div>
#
#
#             <div id="f101c1ec-ca1a-4838-b876-d0f7dfc7d764" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f101c1ec-ca1a-4838-b876-d0f7dfc7d764")) {
#                     Plotly.newPlot(
#                         'f101c1ec-ca1a-4838-b876-d0f7dfc7d764',
# ...
