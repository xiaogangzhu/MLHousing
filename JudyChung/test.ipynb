# %%
import pandas as pd

# %%
raw = pd.read_csv('data/Ames_Housing_Price_Data.csv', index_col=0 )

# %%
from sklearn.model_selection import train_test_split

X = raw.drop('SalePrice', axis=1)
y = raw.SalePrice

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
import clean1

# %%
Xtrain_c = clean1.clean(Xtrain)
#Xtest_c = clean1.clean(Xtest) # for Xtest as well

# %%
Xtrain_c.head()
# Out:
#      GrLivArea  MSSubClass MSZoning LotFrontage  LotArea Street Alley  \
# 998       1728          90       RL          98    13260   Pave  None
# 382       1262          20       RL          80     9600   Pave  None
# 78        1086          80       RL          85    13400   Pave  None
# 417       2582          60       RL          74    11002   Pave  None
# 378       1652          20       RL        None    22002   Pave  None
#
#     LotShape LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence  \
# 998      IR1         Lvl    AllPub  ...           0        0      0  None
# 382      Reg         Lvl    AllPub  ...           0        0      0  None
# 78       Reg         Lvl    AllPub  ...           0        0      0  GdWo
# 417      IR1         Lvl    AllPub  ...           0        0      0  None
# 378      Reg         Lvl    AllPub  ...         201        0      0  None
#
#     MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 998        None       0      1    2010       Oth        Abnorml
# 382        None       0      5    2007       WD          Normal
# 78         None       0      6    2006       WD          Normal
# 417        None       0      1    2007       WD          Normal
# 378        None       0      7    2007       WD          Normal
#
# [5 rows x 79 columns]
